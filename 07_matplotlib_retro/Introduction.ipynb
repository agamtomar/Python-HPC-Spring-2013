# %% [markdown]
# # Visualization
#
# <img src='files/img/art.png' style='width: 300'>
#
# http://kunalanand.com/delicious/
# Created with python!
#
# ## What is it?
#
# - Visual representation of data.
# - Types of plots for today:
#     - scatter
#     - line
#     - box
#     - histogram
#     - density
#
# ## Matplotlib
#
# - publication-quality scientific graphics
# - been around for about 10 years
# - In 5 years, we will probably all be using something different.
#
# ## Current state-of-the-art
#
# <img src='files/img/d3.png' style='width:200'>
#
# - d3 (javascript)
#     - publication-quality
#     - online, interactive visualization
#     - http://d3js.org/
# - But, it's not quick to generate graphs
# - Use simpler tools for exploration
#     - matplotlib (python)
#     - ggplot (R)
#
# ## Where's visualization in python going?
#
# - The Grammar of Graphics
#     - "...concisely describe the components of a graphic. Such a grammar allows us to move beyond named graphics (e.g., the “scatterplot”) and gain insight into the deep structure that underlies statistical graphics" -- Hadley Wickham
#     - Best practices for data exploration
#     - Benefit of R
#     - http://www.amazon.com/Grammar-Graphics-Statistics-Computing/dp/0387245448?tag=viglink123335-20
# - The web!
# - Notebook
# - https://github.com/continuumio/bokeh (not quite ready)
#
# ## Objectives for today
#
# - Understand the mechanics of generating graphs
# - default output looks...
#     - Talk about style
#     - Templates
# - Presentation and print files
#
# ## References
#
#
# - http://www.matplotlib.org
# - http://matplotlib.org/gallery.html
# - http://www.loria.fr/~rougier/teaching/matplotlib/ - Matplotlib tutorial.
# - http://jakevdp.github.io/blog/2012/10/07/xkcd-style-plots-in-matplotlib/
# - http://messymind.net/2012/07/making-matplotlib-look-like-ggplot/

# %% [markdown]
# # Basics
#
# ## Two methods
#
# The `pylab` module (similar to MATLAB)

# %%
from pylab import *

# %% [markdown]
# The `matplotlib.pyplot` module

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# This is the object-oriented approach and has several advantages including:
#
# - No global variables
# - Separates style from graph
# - Can easily have multiple subplots

# %% [markdown]
# ## Figures and Subfigures

# %% [markdown]
# First, we create a blank figure.  Then we add two subpots, both on the same row.

# %%
fig = plt.figure()

ax1 = fig.add_subplot(1,2,1)
ax1.plot(randn(50), color='red')

ax2 = fig.add_subplot(1,2,2)
ax2.scatter(np.arange(50), randn(50))

# %% [markdown]
# ## The `plt.subplots()` command

# %%
fig, ax = plt.subplots(2,3)

ax[0,1].plot(randn(50), color='green', linestyle='-')
ax[1,2].scatter(np.arange(50), randn(50), color='red')
ax[1,0].hist(randn(50))
# Out:
# (array([ 1,  0,  4,  2,  8, 14,  4,  8,  7,  2]),
#  array([-3.15086181, -2.58703266, -2.02320352, -1.45937437, -0.89554523,
#        -0.33171608,  0.23211306,  0.79594221,  1.35977136,  1.9236005 ,
#         2.48742965]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## The `subplot2grid` command

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))
fig.tight_layout()

# %%
fig, axes = plt.subplots( 3, 1, sharex = True)

# %%
fig, axes = plt.subplots( 2, 2, sharex = True, sharey = True)
plt.subplots_adjust( wspace = 0.1, hspace = 0.1)

# %% [markdown]
# ## Style

# %%
lines_types = ['-','-.', ':', 'steps']
lines_marker = ['+', 'o', '*', 's', ',', '.', '1']

# %%
x = np.linspace(0,5,10)

# Figsize is in inches
fig, ax = plt.subplots(1,1, figsize=(9,6))

for i, l in enumerate(lines_types):
    ax.plot(x, x+i, ls=l, lw=2)

for j, l in enumerate(lines_marker):
    ax.plot(x, x+i+j, ls='*', marker=l, markersize=6)
